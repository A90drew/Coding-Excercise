# %% [markdown]
# <a href="https://colab.research.google.com/github/A90drew/Coding-Excercise/blob/main/Exercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt 1 Input:
#
# You are a summarization assistant. Summarize the following article
# for a general (non-technical) audience.
#
# Requirements:
# \- Maximum 150 words
# \- No jargon or technical terms without brief explanation
# \- Cover: what happened, who's involved, why it matters
# \- Neutral tone, no opinions
#
# Article:
# micron-q4-results-summary.md

# %% [markdown]
# Prompt 1 Output:
#
# Micron Technology will report its fourth-quarter results on September 30. Investors are watching to see whether strong demand for memory chips used in artificial intelligence systems will continue to increase the company’s sales and profits.
# Analysts expect Micron to earn far more than it did a year ago, with revenue projected to rise sharply. However, the company’s stock has reacted differently after recent earnings reports, sometimes rising and sometimes falling.
# Major financial firms including UBS, Wells Fargo, and Citi remain generally positive about Micron, citing limited chip supply and continued demand. Still, they are watching whether the company expects this rapid growth to continue. The report matters because Micron’s outlook could affect its stock price and signal how strong demand is for AI-related computer hardware.

# %% [markdown]
# Prompt 2 Input:
#
# Here is the summary you just wrote:
# "Micron Technology will report its fourth-quarter results on September 30. Investors are watching to see whether strong demand for memory chips used in artificial intelligence systems will continue to increase the company’s sales and profits.
# Analysts expect Micron to earn far more than it did a year ago, with revenue projected to rise sharply. However, the company’s stock has reacted differently after recent earnings reports, sometimes rising and sometimes falling.
# Major financial firms including UBS, Wells Fargo, and Citi remain generally positive about Micron, citing limited chip supply and continued demand. Still, they are watching whether the company expects this rapid growth to continue. The report matters because Micron’s outlook could affect its stock price and signal how strong demand is for AI-related computer hardware."
#
# Critique this summary against the following criteria. Be specific
# and honest — point out actual weaknesses, not just generic praise.
#
# 1. Accuracy: Does it include any claims not supported by the original article?
# 2. Clarity: Is there any jargon or confusing phrasing a general reader wouldn't understand?
# 3. Length: Is it at or under 150 words? (If not, by how much?)
# 4. Coverage: Does it clearly convey what happened, who's involved, and why it matters?
#
# List each weakness found, or state "no issues found" for criteria that pass.

# %% [markdown]
# Prompt 2 Output:
#
# Accuracy: No issues found. The claims match the article’s summary.
#
# Clarity: Minor issue: “financial firms” is understandable, but “major banks/analyst firms” may be more precise because UBS, Wells Fargo, and Citi are giving investment research opinions. “AI-related computer hardware” is clear enough for a general reader.
#
# Length: No issues found. It is 109 words, so it is under the 150-word limit.
#
# Coverage: Minor weakness: it clearly explains what is happening and why it matters, but “who’s involved” could be stronger. It names Micron and the three firms, but does not mention that the expected results are based on Wall Street analyst forecasts.

# %% [markdown]
# Prompt 3 Input:
#
# Based on the critique above, rewrite the summary to fix the identified
# issues. Keep it under 150 words, general-audience tone, no jargon.
#
# Original summary:
# "Micron Technology will report its fourth-quarter results on September 30. Investors are watching to see whether strong demand for memory chips used in artificial intelligence systems will continue to increase the company’s sales and profits.
# Analysts expect Micron to earn far more than it did a year ago, with revenue projected to rise sharply. However, the company’s stock has reacted differently after recent earnings reports, sometimes rising and sometimes falling.
# Major financial firms including UBS, Wells Fargo, and Citi remain generally positive about Micron, citing limited chip supply and continued demand. Still, they are watching whether the company expects this rapid growth to continue. The report matters because Micron’s outlook could affect its stock price and signal how strong demand is for AI-related computer hardware."
#
# Critique:
# "{Accuracy: No issues found. The claims match the article’s summary.
# 1. Clarity: Minor issue: “financial firms” is understandable, but “major banks/analyst firms” may be more precise because UBS, Wells Fargo, and Citi are giving investment research opinions. “AI-related computer hardware” is clear enough for a general reader.
# 2. Length: No issues found. It is 109 words, so it is under the 150-word limit.
# 3. Coverage: Minor weakness: it clearly explains what is happening and why it matters, but “who’s involved” could be stronger. It names Micron and the three firms, but does not mention that the expected results are based on Wall Street analyst forecasts."
#
# Provide only the revised summary, no commentary.

# %% [markdown]
# Prompt 3 Output:
#
# Micron Technology will report its fourth-quarter results on September 30. Wall Street analysts expect the company to earn much more and bring in far more revenue than it did a year ago, largely because of demand for memory chips used in artificial intelligence systems.
#
# Investors will watch whether Micron says this growth can continue. Its stock has risen after some recent earnings reports and fallen after others, so the company’s future expectations may be especially important.
#
# Investment research teams at UBS, Wells Fargo, and Citi remain generally positive about Micron. They point to limited chip supply and continued demand as key factors. The report matters because it could affect Micron’s stock price and provide a sign of how strong demand remains for hardware used in AI systems.
