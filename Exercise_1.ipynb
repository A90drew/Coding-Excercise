# %% [markdown]
# <a href="https://colab.research.google.com/github/A90drew/Coding-Excercise/blob/main/Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt 1 Input:
#
# You are a customer support assistant preparing to help a customer.
# Their issue was classified as:
# {prompt 1 output}
#
# Based on this classification, list 2-4 short, specific clarifying
# questions you would ask the customer to resolve their issue.
# Do not ask generic questions like "can you tell me more" — be specific
# to the category (e.g., for billing, ask about dates/amounts; for
# technical, ask about device/browser/error messages).
#
# Format as a numbered list only.

# %% [markdown]
# Prompt 1: Output
#
# Category: billing
# Secondary category (if applicable): technical
# Urgency: high

# %% [markdown]
# Prompt 2 Input:
#
# You are a customer support assistant preparing to help a customer.
# Their issue was classified as:
# Category: billing
# Secondary category (if applicable): technical
# Urgency: high
# Based on this classification, list 2-4 short, specific clarifying
# questions you would ask the customer to resolve their issue.
# Do not ask generic questions like "can you tell me more" — be specific
# to the category (e.g., for billing, ask about dates/amounts; for
# technical, ask about device/browser/error messages).
# Format as a numbered list only.

# %% [markdown]
# Prompt 2 Output:
#
# 1. What are the dates and amounts of the two charges you believe are duplicates?
#
# 2. What payment method was charged (last four digits only)?
#
# 3. Which device and browser are you using when the dashboard fails to load?
#
# 4. Do you see an error message, blank screen, or loading spinner on the dashboard?

# %% [markdown]
# Prompt 3 Input:
#
# You are a customer support assistant drafting a resolution.
#
# Issue classification:
# Category: billing
# Secondary category (if applicable): technical
# Urgency: high
#
# Clarifying questions asked:
# 1. What are the dates and amounts of the two charges you believe are duplicates?
# 2. What payment method was charged (last four digits only)?
# 3. Which device and browser are you using when the dashboard fails to load?
# 4. Do you see an error message, blank screen, or loading spinner on the dashboard?
#
# Customer's answers (made up):
# 1. Both charges were $29.99—one on September 3 and another on September 4.
#
# 2. My Visa ending in 4821 was charged.
#
# 3. I’m using a MacBook with Chrome.
#
# 4. The dashboard shows a loading spinner forever after I sign in.
#
# Write a short, friendly resolution message to the customer (max 120 words).
# Be specific and actionable. Do not promise things you can't confirm
# (e.g., don't guarantee refund timing you don't know).

# %% [markdown]
# Prompt 3 Output:
#
# Thanks for the details. We’ll review the two $29.99 charges from September 3 and 4 on the Visa ending in 4821 to confirm whether one is a duplicate and determine the appropriate next step.
# For the dashboard loading issue, please try opening it in an Incognito Chrome window or clearing your browser cache and cookies, then sign in again. If it still keeps spinning, send us a screenshot and let us know whether it happens on another browser or device.

# %% [markdown]
# Prompt 4 Input:
#
# You are a support escalation classifier.
#
#
#
# Full case so far:
#
# Classification: \
# Category: billing\
# Secondary category (if applicable): technical\
# Urgency: high
#
# Clarifying questions:&#x20;
#
# 1. What are the dates and amounts of the two charges you believe are duplicates?
# 2. What payment method was charged (last four digits only)?
# 3. Which device and browser are you using when the dashboard fails to load?
# 4. Do you see an error message, blank screen, or loading spinner on the dashboard?
#
# Customer answers:
#
# 1. Both charges were $29.99—one on September 3 and another on September 4.
# 2. My Visa ending in 4821 was charged.
# 3. I’m using a MacBook with Chrome.
# 4. The dashboard shows a loading spinner forever after I sign in.
#
# Proposed resolution:
#
# Thanks for the details. We’ll review the two $29.99 charges from September 3 and 4 on the Visa ending in 4821 to confirm whether one is a duplicate and determine the appropriate next step.
#
# For the dashboard loading issue, please try opening it in an Incognito Chrome window or clearing your browser cache and cookies, then sign in again. If it still keeps spinning, send us a screenshot and let us know whether it happens on another browser or device.
#
#
#
# Decide: should this case be escalated to a human agent?
#
# Respond in this format:
#
# Escalate: \<yes | no>
#
# Reason: \<one sentence>

# %% [markdown]
# Prompt 4 Output:
#
# Escalate: yes
# Reason: The potential duplicate charge requires account-specific billing review, while the persistent dashboard failure may need technical investigation
